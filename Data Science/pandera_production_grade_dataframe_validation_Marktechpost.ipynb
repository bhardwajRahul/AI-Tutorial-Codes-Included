# %%
# !pip -q install "pandera>=0.18" pandas numpy polars pyarrow hypothesis

import json
import numpy as np
import pandas as pd
import pandera as pa
from pandera.errors import SchemaError, SchemaErrors
from pandera.typing import Series, DataFrame

print("pandera version:", pa.__version__)
print("pandas  version:", pd.__version__)

# %%
rng = np.random.default_rng(42)

def make_raw_orders(n=250):
    countries = np.array(["CA", "US", "MX"])
    channels = np.array(["web", "mobile", "partner"])
    raw = pd.DataFrame(
        {
            "order_id": rng.integers(1, 120, size=n),
            "customer_id": rng.integers(1, 90, size=n),
            "email": rng.choice(
                ["alice@example.com", "bob@example.com", "bad_email", None],
                size=n,
                p=[0.45, 0.45, 0.07, 0.03],
            ),
            "country": rng.choice(countries, size=n, p=[0.5, 0.45, 0.05]),
            "channel": rng.choice(channels, size=n, p=[0.55, 0.35, 0.10]),
            "items": rng.integers(0, 8, size=n),
            "unit_price": rng.normal(loc=35, scale=20, size=n),
            "discount": rng.choice([0.0, 0.05, 0.10, 0.20, 0.50], size=n, p=[0.55, 0.15, 0.15, 0.12, 0.03]),
            "ordered_at": pd.to_datetime("2025-01-01") + pd.to_timedelta(rng.integers(0, 120, size=n), unit="D"),
        }
    )

    raw.loc[rng.choice(n, size=8, replace=False), "unit_price"] = -abs(raw["unit_price"].iloc[0])
    raw.loc[rng.choice(n, size=6, replace=False), "items"] = 0
    raw.loc[rng.choice(n, size=5, replace=False), "discount"] = 0.9
    raw.loc[rng.choice(n, size=4, replace=False), "country"] = "ZZ"
    raw.loc[rng.choice(n, size=3, replace=False), "channel"] = "unknown"
    raw.loc[rng.choice(n, size=6, replace=False), "unit_price"] = raw["unit_price"].iloc[:6].round(2).astype(str).values

    return raw

raw_orders = make_raw_orders(250)
display(raw_orders.head(10))

# %%
EMAIL_RE = r"^[A-Za-z0-9._%+\-]+@[A-Za-z0-9.\-]+\.[A-Za-z]{2,}$"

class Orders(pa.DataFrameModel):
    order_id: Series[int] = pa.Field(ge=1)
    customer_id: Series[int] = pa.Field(ge=1)
    email: Series[object] = pa.Field(nullable=True)
    country: Series[str] = pa.Field(isin=["CA", "US", "MX"])
    channel: Series[str] = pa.Field(isin=["web", "mobile", "partner"])
    items: Series[int] = pa.Field(ge=1, le=50)
    unit_price: Series[float] = pa.Field(gt=0)
    discount: Series[float] = pa.Field(ge=0.0, le=0.8)
    ordered_at: Series[pd.Timestamp]

    class Config:
        coerce = True
        strict = True
        ordered = False

    @pa.check("email")
    def email_valid(cls, s: pd.Series) -> pd.Series:
        return s.isna() | s.astype(str).str.match(EMAIL_RE)

    @pa.dataframe_check
    def total_value_reasonable(cls, df: pd.DataFrame) -> pd.Series:
        total = df["items"] * df["unit_price"] * (1.0 - df["discount"])
        return total.between(0.01, 5000.0)

    @pa.dataframe_check
    def channel_country_rule(cls, df: pd.DataFrame) -> pd.Series:
        ok = ~((df["channel"] == "partner") & (df["country"] == "MX"))
        return ok

# %%
try:
    validated = Orders.validate(raw_orders, lazy=True)
    print(validated.dtypes)
except SchemaErrors as exc:
    display(exc.failure_cases.head(25))
    err_json = exc.failure_cases.to_dict(orient="records")
    print(json.dumps(err_json[:5], indent=2, default=str))

# %%
def split_clean_quarantine(df: pd.DataFrame):
    try:
        clean = Orders.validate(df, lazy=False)
        return clean, df.iloc[0:0].copy()
    except SchemaError:
        pass

    try:
        Orders.validate(df, lazy=True)
        return df.copy(), df.iloc[0:0].copy()
    except SchemaErrors as exc:
        bad_idx = sorted(set(exc.failure_cases["index"].dropna().astype(int).tolist()))
        quarantine = df.loc[bad_idx].copy()
        clean = df.drop(index=bad_idx).copy()
        return Orders.validate(clean, lazy=False), quarantine

clean_orders, quarantine_orders = split_clean_quarantine(raw_orders)
display(quarantine_orders.head(10))
display(clean_orders.head(10))

@pa.check_types
def enrich_orders(df: DataFrame[Orders]) -> DataFrame[Orders]:
    out = df.copy()
    out["unit_price"] = out["unit_price"].round(2)
    out["discount"] = out["discount"].round(2)
    return out

enriched = enrich_orders(clean_orders)
display(enriched.head(5))

# %%
class EnrichedOrders(Orders):
    total_value: Series[float] = pa.Field(gt=0)

    class Config:
        coerce = True
        strict = True

    @pa.dataframe_check
    def totals_consistent(cls, df: pd.DataFrame) -> pd.Series:
        total = df["items"] * df["unit_price"] * (1.0 - df["discount"])
        return (df["total_value"] - total).abs() <= 1e-6

@pa.check_types
def add_totals(df: DataFrame[Orders]) -> DataFrame[EnrichedOrders]:
    out = df.copy()
    out["total_value"] = out["items"] * out["unit_price"] * (1.0 - out["discount"])
    return EnrichedOrders.validate(out, lazy=False)

enriched2 = add_totals(clean_orders)
display(enriched2.head(5))
# Out:
# pandera version: 0.28.1
# pandas  version: 2.2.2
#
# Raw sample:
# /tmp/ipython-input-4148168637.py:54: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['23.08' '35.17' '50.9' '38.61' '21.88' '59.53']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   raw.loc[rng.choice(n, size=6, replace=False), "unit_price"] = raw["unit_price"].iloc[:6].round(2).astype(str).values
#    order_id  customer_id              email country  channel  items  \
# 0        11           16    bob@example.com      US      web      7
# 1        93           44    bob@example.com      US      web      0
# 2        78           17    bob@example.com      US      web      3
# 3        53           30  alice@example.com      US      web      3
# 4        52           59  alice@example.com      US   mobile      6
# 5       103           13    bob@example.com      US      web      1
# 6        11           61    bob@example.com      CA      web      3
# 7        83           10  alice@example.com      US  partner      1
# 8        24           16  alice@example.com      CA      web      6
# 9        12           53    bob@example.com      ZZ      web      5
#
#   unit_price  discount ordered_at
# 0  23.078222       0.0 2025-03-09
# 1  35.170113       0.0 2025-02-19
# 2  50.898645       0.0 2025-02-22
# 3  38.607279       0.0 2025-02-27
# 4  21.878901       0.5 2025-03-30
# 5  59.525859       0.2 2025-04-14
# 6   66.58371       0.0 2025-03-05
# 7  44.891133       0.9 2025-03-19
# 8   54.47327       0.0 2025-03-30
# 9    59.8392       0.2 2025-03-24
# --- Validating raw_orders with lazy=True (collect all errors) ---
# ❌ Validation failed with multiple errors (SchemaErrors).
#       schema_context   column                   check  check_number  \
# 239  DataFrameSchema  country  total_value_reasonable             0
# 315  DataFrameSchema    items  total_value_reasonable             0
# 327  DataFrameSchema    items  total_value_reasonable             0
# 326  DataFrameSchema    items  total_value_reasonable             0
# 325  DataFrameSchema    items  total_value_reasonable             0
# 324  DataFrameSchema    items  total_value_reasonable             0
# 323  DataFrameSchema    items  total_value_reasonable             0
# 322  DataFrameSchema    items  total_value_reasonable             0
# 321  DataFrameSchema    items  total_value_reasonable             0
# 320  DataFrameSchema    items  total_value_reasonable             0
# 319  DataFrameSchema    items  total_value_reasonable             0
# 318  DataFrameSchema    items  total_value_reasonable             0
# 317  DataFrameSchema    items  total_value_reasonable             0
# 316  DataFrameSchema    items  total_value_reasonable             0
# 314  DataFrameSchema    items  total_value_reasonable             0
# 329  DataFrameSchema    items  total_value_reasonable             0
# 313  DataFrameSchema    items  total_value_reasonable             0
# 312  DataFrameSchema    items  total_value_reasonable             0
# 311  DataFrameSchema    items  total_value_reasonable             0
# 310  DataFrameSchema    items  total_value_reasonable             0
# 309  DataFrameSchema    items  total_value_reasonable             0
# 308  DataFrameSchema    items  total_value_reasonable             0
# 307  DataFrameSchema    items  total_value_reasonable             0
# 306  DataFrameSchema    items  total_value_reasonable             0
# 305  DataFrameSchema    items  total_value_reasonable             0
#
#     failure_case  index
# 239           CA    215
# 315            0    170
# 327            0    222
# 326            2    218
# 325            3    215
# 324            0    214
# 323            0    213
# 322            6    211
# 321            2    203
# 320            0    202
# 319            0    201
# 318            2    192
# 317            3    191
# 316            0    176
# 314            5    157
# 329            2    237
# 313            7    142
# 312            0    137
# 311            0    128
# 310            5    127
# 309            2    126
# 308            5    124
# 307            0     89
# 306            0     81
# 305            0     71
# As JSON (first 5):
# [
#   {
#     "schema_context": "DataFrameSchema",
#     "column": "country",
#     "check": "total_value_reasonable",
#     "check_number": 0,
#     "failure_case": "CA",
#     "index": 215
#   },
#   {
#     "schema_context": "DataFrameSchema",
#     "column": "items",
#     "check": "total_value_reasonable",
#     "check_number": 0,
#     "failure_case": 0,
#     "index": 170
#   },
#   {
#     "schema_context": "DataFrameSchema",
#     "column": "items",
#     "check": "total_value_reasonable",
#     "check_number": 0,
#     "failure_case": 0,
#     "index": 222
#   },
#   {
#     "schema_context": "DataFrameSchema",
#     "column": "items",
#     "check": "total_value_reasonable",
#     "check_number": 0,
#     "failure_case": 2,
#     "index": 218
#   },
#   {
#     "schema_context": "DataFrameSchema",
#     "column": "items",
#     "check": "total_value_reasonable",
#     "check_number": 0,
#     "failure_case": 3,
#     "index": 215
#   }
# ]
#
# --- Quarantine rows that fail validation ---
# clean rows: 184 | quarantined rows: 66
#     order_id  customer_id              email country  channel  items  \
# 1         93           44    bob@example.com      US      web      0
# 7         83           10  alice@example.com      US  partner      1
# 9         12           53    bob@example.com      ZZ      web      5
# 14        86           89          bad_email      CA  partner      5
# 18       100           55  alice@example.com      CA      web      5
# 21        45            3  alice@example.com      CA   mobile      5
# 22        22           14  alice@example.com      CA   mobile      0
# 24        94           38    bob@example.com      CA      web      0
# 31        28           44  alice@example.com      US  partner      1
# 32        11           60  alice@example.com      CA      web      0
#
#    unit_price  discount ordered_at
# 1   35.170113       0.0 2025-02-19
# 7   44.891133       0.9 2025-03-19
# 9     59.8392       0.2 2025-03-24
# 14 -23.078222       0.0 2025-03-20
# 18  61.071301       0.9 2025-01-09
# 21  29.566512       0.9 2025-03-29
# 22  11.955023       0.0 2025-01-11
# 24  37.040626       0.0 2025-04-27
# 31 -23.078222       0.1 2025-01-23
# 32  20.003733       0.5 2025-02-18
#     order_id  customer_id              email country channel  items  \
# 0         11           16    bob@example.com      US     web      7
# 2         78           17    bob@example.com      US     web      3
# 3         53           30  alice@example.com      US     web      3
# 4         52           59  alice@example.com      US  mobile      6
# 5        103           13    bob@example.com      US     web      1
# 6         11           61    bob@example.com      CA     web      3
# 8         24           16  alice@example.com      CA     web      6
# 10        63           71  alice@example.com      CA  mobile      3
# 11       117           16    bob@example.com      US     web      3
# 12        88           27  alice@example.com      CA     web      1
#
#     unit_price  discount ordered_at
# 0    23.078222       0.0 2025-03-09
# 2    50.898645       0.0 2025-02-22
# 3    38.607279       0.0 2025-02-27
# 4    21.878901       0.5 2025-03-30
# 5    59.525859       0.2 2025-04-14
# 6    66.583710       0.0 2025-03-05
# 8    54.473270       0.0 2025-03-30
# 10   57.601986       0.0 2025-01-17
# 11   47.281984       0.2 2025-04-28
# 12   46.966941       0.1 2025-01-20
# --- Function contracts with @pa.check_types ---
#    order_id  customer_id              email country channel  items  \
# 0        11           16    bob@example.com      US     web      7
# 2        78           17    bob@example.com      US     web      3
# 3        53           30  alice@example.com      US     web      3
# 4        52           59  alice@example.com      US  mobile      6
# 5       103           13    bob@example.com      US     web      1
#
#    unit_price  discount ordered_at
# 0       23.08       0.0 2025-03-09
# 2       50.90       0.0 2025-02-22
# 3       38.61       0.0 2025-02-27
# 4       21.88       0.5 2025-03-30
# 5       59.53       0.2 2025-04-14
# --- Schema composition: Enriched schema allows computed columns ---
#    order_id  customer_id              email country channel  items  \
# 0        11           16    bob@example.com      US     web      7
# 2        78           17    bob@example.com      US     web      3
# 3        53           30  alice@example.com      US     web      3
# 4        52           59  alice@example.com      US  mobile      6
# 5       103           13    bob@example.com      US     web      1
#
#    unit_price  discount ordered_at  total_value
# 0   23.078222       0.0 2025-03-09   161.547554
# 2   50.898645       0.0 2025-02-22   152.695935
# 3   38.607279       0.0 2025-02-27   115.821837
# 4   21.878901       0.5 2025-03-30    65.636704
# 5   59.525859       0.2 2025-04-14    47.620687
# Done.
