# %%
import os
import sys
import getpass
from textwrap import dedent

print("Installing CrewAI and tools... (this may take 1-2 mins)")
# !pip install -q crewai crewai-tools

from crewai import Agent, Task, Crew, Process, LLM

# %%
print("\n--- API Authentication ---")
api_key = None

try:
    from google.colab import userdata
    api_key = userdata.get('GEMINI_API_KEY')
    print("✅ Found GEMINI_API_KEY in Colab Secrets.")
except Exception:
    pass

if not api_key:
    print("ℹ️  Key not found in Secrets.")
    api_key = getpass.getpass("🔑 Enter your Google Gemini API Key: ")

os.environ["GEMINI_API_KEY"] = api_key

if not api_key:
    sys.exit("❌ Error: No API Key provided. Please restart and enter a key.")

# %%
gemini_flash = LLM(
    model="gemini/gemini-2.0-flash",
    temperature=0.7
)

# %%
researcher = Agent(
    role='Tech Researcher',
    goal='Uncover cutting-edge developments in AI Agents',
    backstory=dedent("""You are a veteran tech analyst with a knack for finding emerging trends before they become mainstream. You specialize in Autonomous AI Agents and Large Language Models."""),
    verbose=True,
    allow_delegation=False,
    llm=gemini_flash
)

writer = Agent(
    role='Technical Writer',
    goal='Write a concise, engaging blog post about the researcher's findings',
    backstory=dedent("""You transform complex technical concepts into compelling narratives. You write for a developer audience who wants practical insights without fluff."""),
    verbose=True,
    allow_delegation=False,
    llm=gemini_flash
)

# %%
research_task = Task(
    description=dedent("""Conduct a simulated research analysis on 'The Future of Agentic AI in 2025'. Identify 3 key trends: 1. Multi-Agent Orchestration 2. Neuro-symbolic AI 3. On-device Agent execution Provide a brief summary for each based on your 'expert knowledge'."""),
    expected_output="A structured list of 3 key AI trends with brief descriptions.",
    agent=researcher
)

write_task = Task(
    description=dedent("""Using the researcher's findings, write a short blog post (approx 200 words). The post should have: - A catchy title - An intro - The 3 bullet points - A conclusion on why developers should care."""),
    expected_output="A markdown-formatted blog post.",
    agent=writer,
    context=[research_task]
)

# %%
tech_crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True
)

print("\n--- 🤖 Starting the Crew ---")
result = tech_crew.kickoff()

from IPython.display import Markdown
print("\n\n########################")
print("##   FINAL OUTPUT     ##")
print("########################\n")
display(Markdown(str(result)))
# Out:
# Installing CrewAI and tools... (this may take 1-2 mins)
#
# --- API Authentication ---
# ℹ️  Key not found in Secrets.
# 🔑 Enter your Google Gemini API Key: ··········
#
# --- 🤖 Starting the Crew ---
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: dce86b47-36ca-4de3-813b-dfd9c877748b                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Tech Researcher                                                                                         │
# │                                                                                                                 │
# │  Task: Conduct a simulated research analysis on 'The Future of Agentic AI in 2025'.                             │
# │  Identify 3 key trends:                                                                                         │
# │  1. Multi-Agent Orchestration                                                                                   │
# │  2. Neuro-symbolic AI                                                                                           │
# │  3. On-device Agent execution                                                                                   │
# │  Provide a brief summary for each based on your 'expert knowledge'.                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Tech Researcher                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **The Future of Agentic AI in 2025: 3 Key Trends**                                                             │
# │                                                                                                                 │
# │  1.  **Multi-Agent Orchestration:** By 2025, expect to see sophisticated multi-agent systems (MAS) becoming     │
# │  increasingly prevalent. These systems will involve multiple autonomous AI agents collaborating to solve        │
# │  complex problems that are beyond the capabilities of a single agent. Key advancements will focus on efficient  │
# │  communication protocols, conflict resolution mechanisms, and dynamic task allocation strategies. We'll see     │
# │  frameworks that allow agents with diverse skills and knowledge bases to seamlessly interact, negotiate, and    │
# │  coordinate their actions towards a common goal. Applications will span across various industries, including    │
# │  supply chain management (optimizing logistics across multiple vendors), healthcare (coordinating patient care  │
# │  among specialists), and finance (automating complex trading strategies). The rise of MAS will drive the need   │
# │  for robust agent governance and ethical considerations to ensure responsible and aligned behavior across the   │
# │  agent ecosystem. Further research into collective intelligence and swarm intelligence principles will be       │
# │  critical to unlock the full potential of multi-agent orchestration.                                            │
# │                                                                                                                 │
# │  2.  **Neuro-symbolic AI:** The limitations of purely statistical AI models, particularly in reasoning and      │
# │  explainability, will drive the adoption of neuro-symbolic AI. This hybrid approach combines the strengths of   │
# │  neural networks (perception, pattern recognition) with symbolic AI (reasoning, knowledge representation). In   │
# │  2025, expect to see more agentic systems that can leverage neuro-symbolic techniques to perform complex        │
# │  reasoning tasks, understand and manipulate symbolic knowledge, and provide more transparent and explainable    │
# │  decision-making processes. For example, an agent could use a neural network to extract information from        │
# │  unstructured text (e.g., medical records) and then use symbolic reasoning to diagnose a patient based on       │
# │  established medical knowledge. This trend will lead to AI agents that are not only more accurate but also      │
# │  more trustworthy and easier to debug. Key research areas include developing efficient methods for knowledge    │
# │  injection into neural networks, creating robust inference engines for symbolic reasoning, and designing        │
# │  architectures that seamlessly integrate neural and symbolic components.                                        │
# │                                                                                                                 │
# │  3.  **On-device Agent Execution:** The increasing power of edge computing devices (smartphones, IoT devices,   │
# │  embedded systems) will enable more AI agents to run directly on these devices, rather than relying on cloud    │
# │  connectivity. This "on-device" or "edge AI" approach offers several advantages, including reduced latency,     │
# │  increased privacy, and improved resilience to network outages. By 2025, expect to see specialized hardware     │
# │  and software frameworks optimized for running AI agents on resource-constrained devices. Applications will     │
# │  include personalized assistants that can respond instantly to user requests, smart home systems that can       │
# │  adapt to user behavior without sending data to the cloud, and autonomous robots that can navigate and operate  │
# │  in environments with limited connectivity. Challenges include developing efficient model compression           │
# │  techniques, optimizing algorithms for low-power consumption, and ensuring the security and privacy of data     │
# │  processed on-device. Federated learning techniques will also play a crucial role in enabling agents to learn   │
# │  from decentralized data sources without compromising privacy.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technical Writer                                                                                        │
# │                                                                                                                 │
# │  Task: Using the researcher's findings, write a short blog post (approx 200 words).                             │
# │  The post should have:                                                                                          │
# │  - A catchy title                                                                                               │
# │  - An intro                                                                                                     │
# │  - The 3 bullet points                                                                                          │
# │  - A conclusion on why developers should care.                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: ace37e81-cfc0-4edc-9c97-ddeb48341d75                                                                     │
# │  Agent: Tech Researcher                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technical Writer                                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ```markdown                                                                                                    │
# │  ## Agentic AI in 2025: 3 Trends Developers Need to Know                                                        │
# │                                                                                                                 │
# │  The future of AI is agentic – autonomous systems capable of reasoning, acting, and interacting. By 2025,       │
# │  agentic AI will be a game-changer. Here are three key trends that developers should be watching closely:       │
# │                                                                                                                 │
# │  *   **Multi-Agent Orchestration:** Expect to see sophisticated multi-agent systems (MAS) where multiple AI     │
# │  agents collaborate to solve complex problems. This means frameworks enabling agents with diverse skills to     │
# │  seamlessly interact and coordinate. Think supply chain optimization, coordinated healthcare, and automated     │
# │  trading strategies. Get ready to build systems that manage agent communication, conflict resolution, and task  │
# │  allocation.                                                                                                    │
# │                                                                                                                 │
# │  *   **Neuro-symbolic AI:** Purely statistical AI has limitations. Neuro-symbolic AI combines neural networks   │
# │  (perception) with symbolic AI (reasoning). In 2025, agents will leverage this hybrid approach for complex      │
# │  reasoning, knowledge manipulation, and transparent decision-making. Imagine agents diagnosing patients by      │
# │  reasoning over medical records. Start exploring knowledge injection, robust inference engines, and integrated  │
# │  architectures.                                                                                                 │
# │                                                                                                                 │
# │  *   **On-device Agent Execution:** Edge computing power means more AI agents running directly on devices       │
# │  (smartphones, IoT). This offers reduced latency, increased privacy, and resilience. Expect specialized         │
# │  hardware/software for resource-constrained devices. Applications include personalized assistants, smart        │
# │  homes, and autonomous robots. Model compression, low-power algorithms, and on-device data security are         │
# │  crucial skills for developers.                                                                                 │
# │                                                                                                                 │
# │  **Why should developers care?** Agentic AI represents a paradigm shift. These trends will unlock new           │
# │  possibilities across industries, demanding developers with the skills to build, deploy, and manage these       │
# │  intelligent systems. Embrace these advancements now to stay ahead of the curve and shape the future of AI.     │
# │  ```                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
